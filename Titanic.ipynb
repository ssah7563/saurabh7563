# %%
import pandas as pd
import numpy as np

# %%
titanic =pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
titanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
del titanic['Name']

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch  \
# 0            1         0       3    male  22.0      1      0
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
del titanic['Ticket']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Cabin  \
# 0            1         0       3    male  22.0      1      0   7.2500   NaN
# 1            2         1       1  female  38.0      1      0  71.2833   C85
# 2            3         1       3  female  26.0      0      0   7.9250   NaN
# 3            4         1       1  female  35.0      1      0  53.1000  C123
# 4            5         0       3    male  35.0      0      0   8.0500   NaN
#
#   Embarked
# 0        S
# 1        C
# 2        S
# 3        S
# 4        S

# %%
del titanic['Cabin']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0            1         0       3    male  22.0      1      0   7.2500        S
# 1            2         1       1  female  38.0      1      0  71.2833        C
# 2            3         1       3  female  26.0      0      0   7.9250        S
# 3            4         1       1  female  35.0      1      0  53.1000        S
# 4            5         0       3    male  35.0      0      0   8.0500        S

# %%
def getGender(str):
    if str=='male':
        return 1
    else:
        return 0

# %%
titanic['Gender']=titanic['Sex'].apply(getGender)

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0            1         0       3    male  22.0      1      0   7.2500
# 1            2         1       1  female  38.0      1      0  71.2833
# 2            3         1       3  female  26.0      0      0   7.9250
# 3            4         1       1  female  35.0      1      0  53.1000
# 4            5         0       3    male  35.0      0      0   8.0500
#
#   Embarked  Gender
# 0        S       1
# 1        C       0
# 2        S       0
# 3        S       0
# 4        S       1

# %%
del titanic['Sex']
titanic.head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare Embarked  Gender
# 0            1         0       3  22.0      1      0   7.2500        S       1
# 1            2         1       1  38.0      1      0  71.2833        C       0
# 2            3         1       3  26.0      0      0   7.9250        S       0
# 3            4         1       1  35.0      1      0  53.1000        S       0
# 4            5         0       3  35.0      0      0   8.0500        S       1

# %%
titanic=titanic[['PassengerId','Pclass','Age','SibSp','Parch', 'Fare', 'Embarked','Gender','Survived']]
titanic.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare Embarked  Gender  Survived
# 0            1       3  22.0      1      0   7.2500        S       1         0
# 1            2       1  38.0      1      0  71.2833        C       0         1
# 2            3       3  26.0      0      0   7.9250        S       0         1
# 3            4       1  35.0      1      0  53.1000        S       0         1
# 4            5       3  35.0      0      0   8.0500        S       1         0

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# Gender           0
# Survived         0
# dtype: int64

# %%
meanS=titanic[titanic.Survived==1].Age.mean()
meanS
# Out:
# 28.343689655172415

# %%
meanNS=titanic[titanic.Survived==0].Age.mean()
meanNS
# Out:
# 30.62617924528302

# %%
titanic['age']=np.where(pd.isnull(titanic.Age) & titanic['Survived']==1, meanS,titanic['Age'])
titanic.head(20)
# Out:
#     PassengerId  Pclass   Age  SibSp  Parch     Fare Embarked  Gender  \
# 0             1       3  22.0      1      0   7.2500        S       1
# 1             2       1  38.0      1      0  71.2833        C       0
# 2             3       3  26.0      0      0   7.9250        S       0
# 3             4       1  35.0      1      0  53.1000        S       0
# 4             5       3  35.0      0      0   8.0500        S       1
# 5             6       3   NaN      0      0   8.4583        Q       1
# 6             7       1  54.0      0      0  51.8625        S       1
# 7             8       3   2.0      3      1  21.0750        S       1
# 8             9       3  27.0      0      2  11.1333        S       0
# 9            10       2  14.0      1      0  30.0708        C       0
# 10           11       3   4.0      1      1  16.7000        S       0
# 11           12       1  58.0      0      0  26.5500        S       0
# 12           13       3  20.0      0      0   8.0500        S       1
# 13           14       3  39.0      1      5  31.2750        S       1
# 14           15       3  14.0      0      0   7.8542        S       0
# 15           16       2  55.0      0      0  16.0000        S       0
# 16           17       3   2.0      4      1  29.1250        Q       1
# 17           18       2   NaN      0      0  13.0000        S       1
# 18           19       3  31.0      1      0  18.0000        S       0
# 19           20       3   NaN      0      0   7.2250        C       0
#
#     Survived       age
# 0          0  22.00000
# 1          1  38.00000
# 2          1  26.00000
# 3          1  35.00000
# 4          0  35.00000
# 5          0       NaN
# 6          0  54.00000
# 7          0   2.00000
# 8          1  27.00000
# 9          1  14.00000
# 10         1   4.00000
# 11         1  58.00000
# 12         0  20.00000
# 13         0  39.00000
# 14         0  14.00000
# 15         1  55.00000
# 16         0   2.00000
# 17         1  28.34369
# 18         0  31.00000
# 19         1  28.34369

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# Gender           0
# Survived         0
# age            125
# dtype: int64

# %%
titanic.age.fillna(meanNS,inplace=True) # Filling for null value - fillna
titanic.head(20)
# Out:
#     PassengerId  Pclass   Age  SibSp  Parch     Fare Embarked  Gender  \
# 0             1       3  22.0      1      0   7.2500        S       1
# 1             2       1  38.0      1      0  71.2833        C       0
# 2             3       3  26.0      0      0   7.9250        S       0
# 3             4       1  35.0      1      0  53.1000        S       0
# 4             5       3  35.0      0      0   8.0500        S       1
# 5             6       3   NaN      0      0   8.4583        Q       1
# 6             7       1  54.0      0      0  51.8625        S       1
# 7             8       3   2.0      3      1  21.0750        S       1
# 8             9       3  27.0      0      2  11.1333        S       0
# 9            10       2  14.0      1      0  30.0708        C       0
# 10           11       3   4.0      1      1  16.7000        S       0
# 11           12       1  58.0      0      0  26.5500        S       0
# 12           13       3  20.0      0      0   8.0500        S       1
# 13           14       3  39.0      1      5  31.2750        S       1
# 14           15       3  14.0      0      0   7.8542        S       0
# 15           16       2  55.0      0      0  16.0000        S       0
# 16           17       3   2.0      4      1  29.1250        Q       1
# 17           18       2   NaN      0      0  13.0000        S       1
# 18           19       3  31.0      1      0  18.0000        S       0
# 19           20       3   NaN      0      0   7.2250        C       0
#
#     Survived        age
# 0          0  22.000000
# 1          1  38.000000
# 2          1  26.000000
# 3          1  35.000000
# 4          0  35.000000
# 5          0  30.626179
# 6          0  54.000000
# 7          0   2.000000
# 8          1  27.000000
# 9          1  14.000000
# 10         1   4.000000
# 11         1  58.000000
# 12         0  20.000000
# 13         0  39.000000
# 14         0  14.000000
# 15         1  55.000000
# 16         0   2.000000
# 17         1  28.343690
# 18         0  31.000000
# 19         1  28.343690

# %%
titanic.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Age            177
# SibSp            0
# Parch            0
# Fare             0
# Embarked         2
# Gender           0
# Survived         0
# age              0
# dtype: int64

# %%
del titanic['Age']
titanic.head()
# Out:
#    PassengerId  Pclass  SibSp  Parch     Fare Embarked  Gender  Survived   age
# 0            1       3      1      0   7.2500        S       1         0  22.0
# 1            2       1      1      0  71.2833        C       0         1  38.0
# 2            3       3      0      0   7.9250        S       0         1  26.0
# 3            4       1      1      0  53.1000        S       0         1  35.0
# 4            5       3      0      0   8.0500        S       1         0  35.0

# %%
titanic=titanic[['PassengerId','Pclass','age','SibSp','Parch', 'Fare', 'Embarked','Gender','Survived']]
titanic.head()
# Out:
#    PassengerId  Pclass   age  SibSp  Parch     Fare Embarked  Gender  Survived
# 0            1       3  22.0      1      0   7.2500        S       1         0
# 1            2       1  38.0      1      0  71.2833        C       0         1
# 2            3       3  26.0      0      0   7.9250        S       0         1
# 3            4       1  35.0      1      0  53.1000        S       0         1
# 4            5       3  35.0      0      0   8.0500        S       1         0

# %%
print(titanic['Embarked'].unique())
# Out:
# ['S' 'C' 'Q' nan]

# %%
SurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]
SurvivedS
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\2661352295.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==1].shape[0]
# 217

# %%
SurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]
SurvivedC
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\3323632890.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==1].shape[0]
# 93

# %%
SurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==1].shape[0]
SurvivedQ
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\2235321406.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   SurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==1].shape[0]
# 30

# %%
NSurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]
NSurvivedS
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\908403240.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NSurvivedS=titanic[titanic.Embarked=='S'][titanic.Survived==0].shape[0]
# 427

# %%
NSurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
NSurvivedC
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\3258493673.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NSurvivedC=titanic[titanic.Embarked=='C'][titanic.Survived==0].shape[0]
# 75

# %%
NSurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
NSurvivedQ
# Out:
# C:\Users\SHIVAM\AppData\Local\Temp\ipykernel_828\338291469.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   NSurvivedQ=titanic[titanic.Embarked=='Q'][titanic.Survived==0].shape[0]
# 47

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# Gender         0
# Survived       0
# dtype: int64

# %%
titanic.dropna(inplace=True)

# %%
titanic.isnull().sum()
# Out:
# PassengerId    0
# Pclass         0
# age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# Gender         0
# Survived       0
# dtype: int64

# %%
titanic.rename(columns={'age':'Age'},inplace=True)
titanic.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare Embarked  Gender  Survived
# 0            1       3  22.0      1      0   7.2500        S       1         0
# 1            2       1  38.0      1      0  71.2833        C       0         1
# 2            3       3  26.0      0      0   7.9250        S       0         1
# 3            4       1  35.0      1      0  53.1000        S       0         1
# 4            5       3  35.0      0      0   8.0500        S       1         0

# %%
titanic.rename(columns={'Gender':'Sex'},inplace=True)
titanic.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare Embarked  Sex  Survived
# 0            1       3  22.0      1      0   7.2500        S    1         0
# 1            2       1  38.0      1      0  71.2833        C    0         1
# 2            3       3  26.0      0      0   7.9250        S    0         1
# 3            4       1  35.0      1      0  53.1000        S    0         1
# 4            5       3  35.0      0      0   8.0500        S    1         0

# %%
titanic['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
def getEmb(str):
    if str=='S':
        return 1
    elif str=='C':
        return 2
    else:
        return 3
titanic['Embarked']=titanic['Embarked'].apply(getEmb)

titanic.head()
# Out:
#    PassengerId  Pclass   Age  SibSp  Parch     Fare  Embarked  Sex  Survived
# 0            1       3  22.0      1      0   7.2500         1    1         0
# 1            2       1  38.0      1      0  71.2833         2    0         1
# 2            3       3  26.0      0      0   7.9250         1    0         1
# 3            4       1  35.0      1      0  53.1000         1    0         1
# 4            5       3  35.0      0      0   8.0500         1    1         0

# %%
import matplotlib.pyplot as plt
from matplotlib import style

# %%
males=(titanic['Sex']==1).sum()
females=(titanic['Sex']==0).sum()

# %%
print(males)
# Out:
# 577

# %%
print(females)
# Out:
# 312

# %%
p=[males, females]
plt.pie(p, labels=['Male','Female'], colors=['green','yellow'], explode=(0.15,0),startangle=0)
plt.show()

# %%
Male_Sur=titanic[titanic['Sex']==1][titanic.Survived==1].shape[0]
Male_NSur=titanic[titanic['Sex']==1][titanic.Survived==0].shape[0]

# %%
FeMale_Sur=titanic[titanic['Sex']==0][titanic.Survived==1].shape[0]
FeMale_NSur=titanic[titanic['Sex']==0][titanic.Survived==0].shape[0]

# %%
pchart=[Male_Sur,Male_NSur, FeMale_Sur,FeMale_NSur]
plt.pie(pchart,labels=['Male_Sur','Male_NSur', 'FeMale_Sur','FeMale_NSur'],explode=[0,0.05,0,0.1],startangle=100, autopct="%.2f%%")
plt.show()
